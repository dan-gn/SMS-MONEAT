# %%
from scipy.io import arff
import pandas as pd
import numpy as np
from fs_neat import FS_NEAT
from neat import set_seed
import torch
import torch.nn as nn

# %%
data = arff.loadarff('breastCancer-train.arff')
df_train = pd.DataFrame(data[0])

data = arff.loadarff('breastCancer-test.arff')
df_test = pd.DataFrame(data[0])

df_train.shape, df_test.shape
# Out:
# ((78, 24482), (19, 24482))

# %%
df_train.head()
# Out:
#    Contig45645_RC  Contig44916_RC  D25272  J00129  Contig29982_RC  \
# 0          -0.299           0.093  -0.215  -0.566          -0.596
# 1          -0.081           0.009  -0.091  -0.518          -0.502
# 2          -0.125           0.070  -0.006  -0.575          -0.585
# 3          -0.270           0.123   0.056  -0.499          -0.402
# 4          -0.141           0.025  -0.031  -0.465          -0.533
#
#    Contig26811  D25274  Contig36292  Contig42854  Contig34839  ...  NM_000898  \
# 0       -0.195   0.039       -0.409       -0.352        0.066  ...     -0.960
# 1       -0.149   0.098       -0.090        0.138        0.061  ...     -0.531
# 2       -0.183   0.102        0.023       -0.350       -0.005  ...     -0.883
# 3       -0.099  -0.145       -0.103        0.181        0.236  ...     -0.044
# 4       -0.065   0.101       -0.008       -0.019        0.026  ...      0.280
#
#    NM_000899  Contig20164_RC  Contig8985_RC  Contig36062_RC  Contig35333_RC  \
# 0     -0.211           0.155         -0.095          -0.025          -0.037
# 1     -0.020           0.014         -0.123           0.148           0.024
# 2     -0.159           0.022          0.006          -0.086           0.019
# 3     -0.096           0.018          0.000           0.076           0.057
# 4     -0.088           0.043          0.207          -0.124          -0.041
#
#    Contig62037_RC  AF067420  Contig15167_RC       Class
# 0           0.215     0.307           0.321  b'relapse'
# 1          -0.070    -0.209           0.105  b'relapse'
# 2           0.026    -0.822           0.199  b'relapse'
# 3          -0.016    -0.360          -0.038  b'relapse'
# 4          -0.077    -0.432          -0.015  b'relapse'
#
# [5 rows x 24482 columns]

# %%
df_train['Class'].unique()
# Out:
# array([b'relapse', b'non-relapse'], dtype=object)

# %%
labels = {b'relapse' : 1, b'non-relapse' : 0}
df_train['Class'] = df_train['Class'].replace(labels)
df_test['Class'] = df_test['Class'].replace(labels)

# %%
x_train = df_train.iloc[:, :-1].to_numpy(dtype=np.float32)
y_train = df_train.iloc[:, -1].to_numpy(dtype=np.float32)
y_train = np.expand_dims(y_train, axis=1)

x_test = df_test.iloc[:, :-1].to_numpy(dtype=np.float32)
bias = np.ones((x_test.shape[0], 1))
x_test = np.concatenate((bias, x_test), axis=1)
y_test = df_test.iloc[:, -1].to_numpy(dtype=np.float32)
y_test = np.expand_dims(y_test, axis=1)

x_test = torch.from_numpy(x_test).type(torch.float32)
y_test = torch.from_numpy(y_test).type(torch.float32)

x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((78, 24481), (78, 1), torch.Size([19, 24482]), torch.Size([19, 1]))

# %%
params = {
	'max_iterations' : 2000,
	'n_population' : 200, 
	'initial_weight_limits' : [-5, 5],
	'input_bias' : True, 
	'activation_function' : nn.ReLU(),
	'activation_coeff' : 1.0,
	'crossover_prob' : 0.75,
	'disable_node_prob' : 0.75,
	'interspecies_mating_rate' : 0.001,
	'weight_mutation_prob' : 0.05,
	'pol_mutation_distr' : 5,
	'weight_mutation_sustitution_prob' : 0.1,
	'add_node_prob' : 0.15,
	'add_connection_prob' : 0.8,
	'compatibility_threshold' : 3,
	'compatibility_distance_coeff' : [1.0, 1.0, 0.4],
	'stagnant_generations_threshold' : 15,
	'champion_elitism_threshold' : 5
}

problem = {
	'x' : x_train,
	'y' : y_train
}

# %%
set_seed()
neat = FS_NEAT(problem, params)
neat.run()
neat.best_solution.describe()
# Out:
# Iteration: 0, Best solution fitness : 99.11334991455078
# Iteration: 1, Best solution fitness : 99.11334991455078
# Iteration: 2, Best solution fitness : 99.11334991455078
# Iteration: 3, Best solution fitness : 99.11902618408203
# Iteration: 4, Best solution fitness : 99.11902618408203
# Iteration: 5, Best solution fitness : 99.11902618408203
# Iteration: 6, Best solution fitness : 99.11907958984375
# Iteration: 7, Best solution fitness : 99.12486267089844
# Iteration: 8, Best solution fitness : 99.12486267089844
# Iteration: 9, Best solution fitness : 99.12486267089844
# Iteration: 10, Best solution fitness : 99.12486267089844
# Iteration: 11, Best solution fitness : 99.12486267089844
# Iteration: 12, Best solution fitness : 99.12486267089844
# Iteration: 13, Best solution fitness : 99.12486267089844
# Iteration: 14, Best solution fitness : 99.12486267089844
# Iteration: 15, Best solution fitness : 99.12486267089844
# Iteration: 16, Best solution fitness : 99.12486267089844
# Iteration: 17, Best solution fitness : 99.12486267089844
# Iteration: 18, Best solution fitness : 99.12486267089844
# Iteration: 19, Best solution fitness : 99.12486267089844
# Iteration: 20, Best solution fitness : 99.12486267089844
# Iteration: 21, Best solution fitness : 99.12486267089844
# Iteration: 22, Best solution fitness : 99.12486267089844
# Iteration: 23, Best solution fitness : 99.12486267089844
# Iteration: 24, Best solution fitness : 99.12486267089844
# Iteration: 25, Best solution fitness : 99.12552642822266
# Iteration: 26, Best solution fitness : 99.12552642822266
# Iteration: 27, Best solution fitness : 99.12881469726562
# Iteration: 28, Best solution fitness : 99.12881469726562
# Iteration: 29, Best solution fitness : 99.12881469726562
# Iteration: 30, Best solution fitness : 99.12903594970703
# Iteration: 31, Best solution fitness : 99.12913513183594
# Iteration: 32, Best solution fitness : 99.12913513183594
# Iteration: 33, Best solution fitness : 99.12913513183594
# Iteration: 34, Best solution fitness : 99.12913513183594
# Iteration: 35, Best solution fitness : 99.12921905517578
# Iteration: 36, Best solution fitness : 99.13121032714844
# Iteration: 37, Best solution fitness : 99.13121032714844
# Iteration: 38, Best solution fitness : 99.1326904296875
# Iteration: 39, Best solution fitness : 99.1326904296875
# Iteration: 40, Best solution fitness : 99.1326904296875
# Iteration: 41, Best solution fitness : 99.1326904296875
# Iteration: 42, Best solution fitness : 99.1326904296875
# Iteration: 43, Best solution fitness : 99.15933227539062
# Iteration: 44, Best solution fitness : 99.15933227539062
# Iteration: 45, Best solution fitness : 99.15933227539062
# Iteration: 46, Best solution fitness : 99.15933227539062
# Iteration: 47, Best solution fitness : 99.15933227539062
# Iteration: 48, Best solution fitness : 99.15933227539062
# Iteration: 49, Best solution fitness : 99.15933227539062
# Iteration: 50, Best solution fitness : 99.15933227539062
# Iteration: 51, Best solution fitness : 99.16226196289062
# Iteration: 52, Best solution fitness : 99.16226196289062
# Iteration: 53, Best solution fitness : 99.16226196289062
# Iteration: 54, Best solution fitness : 99.17522430419922
# Iteration: 55, Best solution fitness : 99.17522430419922
# Iteration: 56, Best solution fitness : 99.17522430419922
# Iteration: 57, Best solution fitness : 99.17522430419922
# Iteration: 58, Best solution fitness : 99.17522430419922
# Iteration: 59, Best solution fitness : 99.17522430419922
# Iteration: 60, Best solution fitness : 99.17522430419922
# Iteration: 61, Best solution fitness : 99.18292236328125
# Iteration: 62, Best solution fitness : 99.18436431884766
# Iteration: 63, Best solution fitness : 99.18436431884766
# Iteration: 64, Best solution fitness : 99.18436431884766
# Iteration: 65, Best solution fitness : 99.18551635742188
# Iteration: 66, Best solution fitness : 99.20073699951172
# Iteration: 67, Best solution fitness : 99.20073699951172
# Iteration: 68, Best solution fitness : 99.20073699951172
# Iteration: 69, Best solution fitness : 99.20073699951172
# Iteration: 70, Best solution fitness : 99.20073699951172
# Iteration: 71, Best solution fitness : 99.20318603515625
# Iteration: 72, Best solution fitness : 99.20318603515625
# Iteration: 73, Best solution fitness : 99.20318603515625
# Iteration: 74, Best solution fitness : 99.20318603515625
# Iteration: 75, Best solution fitness : 99.2037124633789
# Iteration: 76, Best solution fitness : 99.2037124633789
# Iteration: 77, Best solution fitness : 99.2037124633789
# Iteration: 78, Best solution fitness : 99.2037124633789
# Iteration: 79, Best solution fitness : 99.2037124633789
# Iteration: 80, Best solution fitness : 99.2037124633789
# Iteration: 81, Best solution fitness : 99.21260070800781
# Iteration: 82, Best solution fitness : 99.21260070800781
# Iteration: 83, Best solution fitness : 99.21432495117188
# Iteration: 84, Best solution fitness : 99.21432495117188
# Iteration: 85, Best solution fitness : 99.21432495117188
# Iteration: 86, Best solution fitness : 99.21432495117188
# Iteration: 87, Best solution fitness : 99.21432495117188
# Iteration: 88, Best solution fitness : 99.21432495117188
# Iteration: 89, Best solution fitness : 99.21432495117188
# Iteration: 90, Best solution fitness : 99.21432495117188
# Iteration: 91, Best solution fitness : 99.21432495117188
# Iteration: 92, Best solution fitness : 99.21432495117188
# Iteration: 93, Best solution fitness : 99.21432495117188
# Iteration: 94, Best solution fitness : 99.21432495117188
# Iteration: 95, Best solution fitness : 99.21432495117188
# Iteration: 96, Best solution fitness : 99.21432495117188
# Iteration: 97, Best solution fitness : 99.21432495117188
# Iteration: 98, Best solution fitness : 99.21478271484375
# Iteration: 99, Best solution fitness : 99.21478271484375
# Node genes:
# Node 0, type input, layer 0
# Node 1, type input, layer 0
# Node 2, type input, layer 0
# Node 3, type input, layer 0
# Node 4, type input, layer 0
# Node 5, type input, layer 0
# Node 6, type input, layer 0
# Node 7, type input, layer 0
# Node 8, type input, layer 0
# Node 9, type input, layer 0
# Node 10, type input, layer 0
# Node 11, type input, layer 0
# Node 12, type input, layer 0
# Node 13, type input, layer 0
# Node 14, type input, layer 0
# Node 15, type input, layer 0
# Node 16, type input, layer 0
# Node 17, type input, layer 0
# Node 18, type input, layer 0
# Node 19, type input, layer 0
# Node 20, type input, layer 0
# Node 21, type input, layer 0
# Node 22, type input, layer 0
# Node 23, type input, layer 0
# Node 24, type input, layer 0
# Node 25, type input, layer 0
# Node 26, type input, layer 0
# Node 27, type input, layer 0
# Node 28, type input, layer 0
# Node 29, type input, layer 0
# Node 30, type input, layer 0
# Node 31, type input, layer 0
# Node 32, type input, layer 0
# Node 33, type input, layer 0
# Node 34, type input, layer 0
# Node 35, type input, layer 0
# Node 36, type input, layer 0
# Node 37, type input, layer 0
# Node 38, type input, layer 0
# Node 39, type input, layer 0
# Node 40, type input, layer 0
# Node 41, type input, layer 0
# Node 42, type input, layer 0
# Node 43, type input, layer 0
# Node 44, type input, layer 0
# Node 45, type input, layer 0
# Node 46, type input, layer 0
# Node 47, type input, layer 0
# Node 48, type input, layer 0
# Node 49, type input, layer 0
# Node 50, type input, layer 0
# Node 51, type input, layer 0
# Node 52, type input, layer 0
# Node 53, type input, layer 0
# Node 54, type input, layer 0
# Node 55, type input, layer 0
# Node 56, type input, layer 0
# Node 57, type input, layer 0
# Node 58, type input, layer 0
# Node 59, type input, layer 0
# Node 60, type input, layer 0
# Node 61, type input, layer 0
# Node 62, type input, layer 0
# Node 63, type input, layer 0
# Node 64, type input, layer 0
# Node 65, type input, layer 0
# Node 66, type input, layer 0
# Node 67, type input, layer 0
# Node 68, type input, layer 0
# Node 69, type input, layer 0
# Node 70, type input, layer 0
# Node 71, type input, layer 0
# Node 72, type input, layer 0
# Node 73, type input, layer 0
# Node 74, type input, layer 0
# Node 75, type input, layer 0
# Node 76, type input, layer 0
# Node 77, type input, layer 0
# Node 78, type input, layer 0
# Node 79, type input, layer 0
# Node 80, type input, layer 0
# Node 81, type input, layer 0
# Node 82, type input, layer 0
# Node 83, type input, layer 0
# Node 84, type input, layer 0
# Node 85, type input, layer 0
# Node 86, type input, layer 0
# Node 87, type input, layer 0
# Node 88, type input, layer 0
# Node 89, type input, layer 0
# Node 90, type input, layer 0
# Node 91, type input, layer 0
# Node 92, type input, layer 0
# Node 93, type input, layer 0
# Node 94, type input, layer 0
# Node 95, type input, layer 0
# Node 96, type input, layer 0
# Node 97, type input, layer 0
# Node 98, type input, layer 0
# Node 99, type input, layer 0
# Node 100, type input, layer 0
# Node 101, type input, layer 0
# Node 102, type input, layer 0
# Node 103, type input, layer 0
# Node 104, type input, layer 0
# Node 105, type input, layer 0
# Node 106, type input, layer 0
# Node 107, type input, layer 0
# Node 108, type input, layer 0
# Node 109, type input, layer 0
# Node 110, type input, layer 0
# Node 111, type input, layer 0
# Node 112, type input, layer 0
# Node 113, type input, layer 0
# Node 114, type input, layer 0
# Node 115, type input, layer 0
# Node 116, type input, layer 0
# Node 117, type input, layer 0
# Node 118, type input, layer 0
# Node 119, type input, layer 0
# Node 120, type input, layer 0
# Node 121, type input, layer 0
# Node 122, type input, layer 0
# Node 123, type input, layer 0
# Node 124, type input, layer 0
# Node 125, type input, layer 0
# Node 126, type input, layer 0
# Node 127, type input, layer 0
# Node 128, type input, layer 0
# Node 129, type input, layer 0
# Node 130, type input, layer 0
# Node 131, type input, layer 0
# Node 132, type input, layer 0
# Node 133, type input, layer 0
# Node 134, type input, layer 0
# Node 135, type input, layer 0
# Node 136, type input, layer 0
# Node 137, type input, layer 0
# Node 138, type input, layer 0
# Node 139, type input, layer 0
# Node 140, type input, layer 0
# Node 141, type input, layer 0
# Node 142, type input, layer 0
# Node 143, type input, layer 0
# Node 144, type input, layer 0
# Node 145, type input, layer 0
# Node 146, type input, layer 0
# Node 147, type input, layer 0
# Node 148, type input, layer 0
# Node 149, type input, layer 0
# Node 150, type input, layer 0
# Node 151, type input, layer 0
# Node 152, type input, layer 0
# Node 153, type input, layer 0
# Node 154, type input, layer 0
# Node 155, type input, layer 0
# Node 156, type input, layer 0
# Node 157, type input, layer 0
# Node 158, type input, layer 0
# Node 159, type input, layer 0
# Node 160, type input, layer 0
# Node 161, type input, layer 0
# Node 162, type input, layer 0
# Node 163, type input, layer 0
# Node 164, type input, layer 0
# Node 165, type input, layer 0
# Node 166, type input, layer 0
# Node 167, type input, layer 0
# Node 168, type input, layer 0
# Node 169, type input, layer 0
# Node 170, type input, layer 0
# Node 171, type input, layer 0
# Node 172, type input, layer 0
# Node 173, type input, layer 0
# Node 174, type input, layer 0
# Node 175, type input, layer 0
# Node 176, type input, layer 0
# Node 177, type input, layer 0
# Node 178, type input, layer 0
# Node 179, type input, layer 0
# Node 180, type input, layer 0
# Node 181, type input, layer 0
# Node 182, type input, layer 0
# Node 183, type input, layer 0
# Node 184, type input, layer 0
# Node 185, type input, layer 0
# Node 186, type input, layer 0
# Node 187, type input, layer 0
# Node 188, type input, layer 0
# Node 189, type input, layer 0
# Node 190, type input, layer 0
# Node 191, type input, layer 0
# Node 192, type input, layer 0
# Node 193, type input, layer 0
# Node 194, type input, layer 0
# Node 195, type input, layer 0
# Node 196, type input, layer 0
# Node 197, type input, layer 0
# Node 198, type input, layer 0
# Node 199, type input, layer 0
# Node 200, type input, layer 0
# Node 201, type input, layer 0
# Node 202, type input, layer 0
# Node 203, type input, layer 0
# Node 204, type input, layer 0
# Node 205, type input, layer 0
# Node 206, type input, layer 0
# Node 207, type input, layer 0
# Node 208, type input, layer 0
# Node 209, type input, layer 0
# Node 210, type input, layer 0
# Node 211, type input, layer 0
# Node 212, type input, layer 0
# Node 213, type input, layer 0
# Node 214, type input, layer 0
# Node 215, type input, layer 0
# Node 216, type input, layer 0
# Node 217, type input, layer 0
# Node 218, type input, layer 0
# Node 219, type input, layer 0
# Node 220, type input, layer 0
# Node 221, type input, layer 0
# Node 222, type input, layer 0
# Node 223, type input, layer 0
# Node 224, type input, layer 0
# Node 225, type input, layer 0
# Node 226, type input, layer 0
# Node 227, type input, layer 0
# Node 228, type input, layer 0
# Node 229, type input, layer 0
# Node 230, type input, layer 0
# Node 231, type input, layer 0
# Node 232, type input, layer 0
# Node 233, type input, layer 0
# Node 234, type input, layer 0
# Node 235, type input, layer 0
# Node 236, type input, layer 0
# Node 237, type input, layer 0
# Node 238, type input, layer 0
# Node 239, type input, layer 0
# Node 240, type input, layer 0
# Node 241, type input, layer 0
# Node 242, type input, layer 0
# Node 243, type input, layer 0
# Node 244, type input, layer 0
# Node 245, type input, layer 0
# Node 246, type input, layer 0
# Node 247, type input, layer 0
# Node 248, type input, layer 0
# Node 249, type input, layer 0
# Node 250, type input, layer 0
# Node 251, type input, layer 0
# Node 252, type input, layer 0
# Node 253, type input, layer 0
# Node 254, type input, layer 0
# Node 255, type input, layer 0
# Node 256, type input, layer 0
# Node 257, type input, layer 0
# Node 258, type input, layer 0
# Node 259, type input, layer 0
# Node 260, type input, layer 0
# Node 261, type input, layer 0
# Node 262, type input, layer 0
# Node 263, type input, layer 0
# Node 264, type input, layer 0
# Node 265, type input, layer 0
# Node 266, type input, layer 0
# Node 267, type input, layer 0
# Node 268, type input, layer 0
# Node 269, type input, layer 0
# Node 270, type input, layer 0
# Node 271, type input, layer 0
# Node 272, type input, layer 0
# Node 273, type input, layer 0
# Node 274, type input, layer 0
# Node 275, type input, layer 0
# Node 276, type input, layer 0
# Node 277, type input, layer 0
# Node 278, type input, layer 0
# Node 279, type input, layer 0
# Node 280, type input, layer 0
# Node 281, type input, layer 0
# Node 282, type input, layer 0
# Node 283, type input, layer 0
# Node 284, type input, layer 0
# Node 285, type input, layer 0
# Node 286, type input, layer 0
# Node 287, type input, layer 0
# Node 288, type input, layer 0
# Node 289, type input, layer 0
# Node 290, type input, layer 0
# Node 291, type input, layer 0
# Node 292, type input, layer 0
# Node 293, type input, layer 0
# Node 294, type input, layer 0
# Node 295, type input, layer 0
# Node 296, type input, layer 0
# Node 297, type input, layer 0
# Node 298, type input, layer 0
# Node 299, type input, layer 0
# Node 300, type input, layer 0
# Node 301, type input, layer 0
# Node 302, type input, layer 0
# Node 303, type input, layer 0
# Node 304, type input, layer 0
# Node 305, type input, layer 0
# Node 306, type input, layer 0
# Node 307, type input, layer 0
# Node 308, type input, layer 0
# Node 309, type input, layer 0
# Node 310, type input, layer 0
# Node 311, type input, layer 0
# Node 312, type input, layer 0
# Node 313, type input, layer 0
# Node 314, type input, layer 0
# Node 315, type input, layer 0
# Node 316, type input, layer 0
# Node 317, type input, layer 0
# Node 318, type input, layer 0
# Node 319, type input, layer 0
# Node 320, type input, layer 0
# Node 321, type input, layer 0
# Node 322, type input, layer 0
# Node 323, type input, layer 0
# Node 324, type input, layer 0
# Node 325, type input, layer 0
# Node 326, type input, layer 0
# Node 327, type input, layer 0
# Node 328, type input, layer 0
# Node 329, type input, layer 0
# Node 330, type input, layer 0
# Node 331, type input, layer 0
# Node 332, type input, layer 0
# Node 333, type input, layer 0
# Node 334, type input, layer 0
# Node 335, type input, layer 0
# Node 336, type input, layer 0
# Node 337, type input, layer 0
# Node 338, type input, layer 0
# Node 339, type input, layer 0
# Node 340, type input, layer 0
# Node 341, type input, layer 0
# Node 342, type input, layer 0
# Node 343, type input, layer 0
# Node 344, type input, layer 0
# Node 345, type input, layer 0
# Node 346, type input, layer 0
# Node 347, type input, layer 0
# Node 348, type input, layer 0
# Node 349, type input, layer 0
# Node 350, type input, layer 0
# Node 351, type input, layer 0
# Node 352, type input, layer 0
# Node 353, type input, layer 0
# Node 354, type input, layer 0
# Node 355, type input, layer 0
# Node 356, type input, layer 0
# Node 357, type input, layer 0
# Node 358, type input, layer 0
# Node 359, type input, layer 0
# Node 360, type input, layer 0
# Node 361, type input, layer 0
# Node 362, type input, layer 0
# Node 363, type input, layer 0
# Node 364, type input, layer 0
# Node 365, type input, layer 0
# Node 366, type input, layer 0
# Node 367, type input, layer 0
# Node 368, type input, layer 0
# Node 369, type input, layer 0
# Node 370, type input, layer 0
# Node 371, type input, layer 0
# Node 372, type input, layer 0
# Node 373, type input, layer 0
# Node 374, type input, layer 0
# Node 375, type input, layer 0
# Node 376, type input, layer 0
# Node 377, type input, layer 0
# Node 378, type input, layer 0
# Node 379, type input, layer 0
# Node 380, type input, layer 0
# Node 381, type input, layer 0
# Node 382, type input, layer 0
# Node 383, type input, layer 0
# Node 384, type input, layer 0
# Node 385, type input, layer 0
# Node 386, type input, layer 0
# Node 387, type input, layer 0
# Node 388, type input, layer 0
# Node 389, type input, layer 0
# Node 390, type input, layer 0
# Node 391, type input, layer 0
# Node 392, type input, layer 0
# Node 393, type input, layer 0
# Node 394, type input, layer 0
# Node 395, type input, layer 0
# Node 396, type input, layer 0
# Node 397, type input, layer 0
# Node 398, type input, layer 0
# Node 399, type input, layer 0
# Node 400, type input, layer 0
# Node 401, type input, layer 0
# Node 402, type input, layer 0
# Node 403, type input, layer 0
# Node 404, type input, layer 0
# Node 405, type input, layer 0
# Node 406, type input, layer 0
# Node 407, type input, layer 0
# Node 408, type input, layer 0
# Node 409, type input, layer 0
# Node 410, type input, layer 0
# Node 411, type input, layer 0
# Node 412, type input, layer 0
# Node 413, type input, layer 0
# Node 414, type input, layer 0
# Node 415, type input, layer 0
# Node 416, type input, layer 0
# Node 417, type input, layer 0
# Node 418, type input, layer 0
# Node 419, type input, layer 0
# Node 420, type input, layer 0
# Node 421, type input, layer 0
# Node 422, type input, layer 0
# Node 423, type input, layer 0
# Node 424, type input, layer 0
# Node 425, type input, layer 0
# Node 426, type input, layer 0
# Node 427, type input, layer 0
# Node 428, type input, layer 0
# Node 429, type input, layer 0
# Node 430, type input, layer 0
# Node 431, type input, layer 0
# Node 432, type input, layer 0
# Node 433, type input, layer 0
# Node 434, type input, layer 0
# Node 435, type input, layer 0
# Node 436, type input, layer 0
# Node 437, type input, layer 0
# Node 438, type input, layer 0
# Node 439, type input, layer 0
# Node 440, type input, layer 0
# Node 441, type input, layer 0
# Node 442, type input, layer 0
# Node 443, type input, layer 0
# Node 444, type input, layer 0
# Node 445, type input, layer 0
# Node 446, type input, layer 0
# Node 447, type input, layer 0
# Node 448, type input, layer 0
# Node 449, type input, layer 0
# Node 450, type input, layer 0
# Node 451, type input, layer 0
# Node 452, type input, layer 0
# Node 453, type input, layer 0
# Node 454, type input, layer 0
# Node 455, type input, layer 0
# Node 456, type input, layer 0
# Node 457, type input, layer 0
# Node 458, type input, layer 0
# Node 459, type input, layer 0
# Node 460, type input, layer 0
# Node 461, type input, layer 0
# Node 462, type input, layer 0
# Node 463, type input, layer 0
# Node 464, type input, layer 0
# Node 465, type input, layer 0
# Node 466, type input, layer 0
# Node 467, type input, layer 0
# Node 468, type input, layer 0
# Node 469, type input, layer 0
# Node 470, type input, layer 0
# Node 471, type input, layer 0
# Node 472, type input, layer 0
# Node 473, type input, layer 0
# Node 474, type input, layer 0
# Node 475, type input, layer 0
# Node 476, type input, layer 0
# Node 477, type input, layer 0
# Node 478, type input, layer 0
# Node 479, type input, layer 0
# Node 480, type input, layer 0
# Node 481, type input, layer 0
# Node 482, type input, layer 0
# Node 483, type input, layer 0
# Node 484, type input, layer 0
# Node 485, type input, layer 0
# Node 486, type input, layer 0
# Node 487, type input, layer 0
# Node 488, type input, layer 0
# Node 489, type input, layer 0
# Node 490, type input, layer 0
# Node 491, type input, layer 0
# Node 492, type input, layer 0
# Node 493, type input, layer 0
# Node 494, type input, layer 0
# Node 495, type input, layer 0
# Node 496, type input, layer 0
# Node 497, type input, layer 0
# Node 498, type input, layer 0
# Node 499, type input, layer 0
# Node 500, type input, layer 0
# Node 501, type input, layer 0
# Node 502, type input, layer 0
# Node 503, type input, layer 0
# Node 504, type input, layer 0
# Node 505, type input, layer 0
# Node 506, type input, layer 0
# Node 507, type input, layer 0
# Node 508, type input, layer 0
# Node 509, type input, layer 0
# Node 510, type input, layer 0
# Node 511, type input, layer 0
# Node 512, type input, layer 0
# Node 513, type input, layer 0
# Node 514, type input, layer 0
# Node 515, type input, layer 0
# Node 516, type input, layer 0
# Node 517, type input, layer 0
# Node 518, type input, layer 0
# Node 519, type input, layer 0
# Node 520, type input, layer 0
# Node 521, type input, layer 0
# Node 522, type input, layer 0
# Node 523, type input, layer 0
# Node 524, type input, layer 0
# Node 525, type input, layer 0
# Node 526, type input, layer 0
# Node 527, type input, layer 0
# Node 528, type input, layer 0
# Node 529, type input, layer 0
# Node 530, type input, layer 0
# Node 531, type input, layer 0
# Node 532, type input, layer 0
# Node 533, type input, layer 0
# Node 534, type input, layer 0
# Node 535, type input, layer 0
# Node 536, type input, layer 0
# Node 537, type input, layer 0
# Node 538, type input, layer 0
# Node 539, type input, layer 0
# Node 540, type input, layer 0
# Node 541, type input, layer 0
# Node 542, type input, layer 0
# Node 543, type input, layer 0
# Node 544, type input, layer 0
# Node 545, type input, layer 0
# Node 546, type input, layer 0
# Node 547, type input, layer 0
# Node 548, type input, layer 0
# Node 549, type input, layer 0
# Node 550, type input, layer 0
# Node 551, type input, layer 0
# Node 552, type input, layer 0
# Node 553, type input, layer 0
# Node 554, type input, layer 0
# Node 555, type input, layer 0
# Node 556, type input, layer 0
# Node 557, type input, layer 0
# Node 558, type input, layer 0
# Node 559, type input, layer 0
# Node 560, type input, layer 0
# Node 561, type input, layer 0
# Node 562, type input, layer 0
# Node 563, type input, layer 0
# Node 564, type input, layer 0
# Node 565, type input, layer 0
# Node 566, type input, layer 0
# Node 567, type input, layer 0
# Node 568, type input, layer 0
# Node 569, type input, layer 0
# Node 570, type input, layer 0
# Node 571, type input, layer 0
# Node 572, type input, layer 0
# Node 573, type input, layer 0
# Node 574, type input, layer 0
# Node 575, type input, layer 0
# Node 576, type input, layer 0
# Node 577, type input, layer 0
# Node 578, type input, layer 0
# Node 579, type input, layer 0
# Node 580, type input, layer 0
# Node 581, type input, layer 0
# Node 582, type input, layer 0
# Node 583, type input, layer 0
# Node 584, type input, layer 0
# Node 585, type input, layer 0
# Node 586, type input, layer 0
# Node 587, type input, layer 0
# Node 588, type input, layer 0
# Node 589, type input, layer 0
# Node 590, type input, layer 0
# Node 591, type input, layer 0
# Node 592, type input, layer 0
# Node 593, type input, layer 0
# Node 594, type input, layer 0
# Node 595, type input, layer 0
# Node 596, type input, layer 0
# Node 597, type input, layer 0
# Node 598, type input, layer 0
# Node 599, type input, layer 0
# Node 600, type input, layer 0
# Node 601, type input, layer 0
# Node 602, type input, layer 0
# Node 603, type input, layer 0
# Node 604, type input, layer 0
# Node 605, type input, layer 0
# Node 606, type input, layer 0
# Node 607, type input, layer 0
# Node 608, type input, layer 0
# Node 609, type input, layer 0
# Node 610, type input, layer 0
# Node 611, type input, layer 0
# Node 612, type input, layer 0
# Node 613, type input, layer 0
# Node 614, type input, layer 0
# Node 615, type input, layer 0
# Node 616, type input, layer 0
# Node 617, type input, layer 0
# Node 618, type input, layer 0
# Node 619, type input, layer 0
# Node 620, type input, layer 0
# Node 621, type input, layer 0
# Node 622, type input, layer 0
# Node 623, type input, layer 0
# Node 624, type input, layer 0
# Node 625, type input, layer 0
# Node 626, type input, layer 0
# Node 627, type input, layer 0
# Node 628, type input, layer 0
# Node 629, type input, layer 0
# Node 630, type input, layer 0
# Node 631, type input, layer 0
# Node 632, type input, layer 0
# Node 633, type input, layer 0
# Node 634, type input, layer 0
# Node 635, type input, layer 0
# Node 636, type input, layer 0
# Node 637, type input, layer 0
# Node 638, type input, layer 0
# Node 639, type input, layer 0
# Node 640, type input, layer 0
# Node 641, type input, layer 0
# Node 642, type input, layer 0
# Node 643, type input, layer 0
# Node 644, type input, layer 0
# Node 645, type input, layer 0
# Node 646, type input, layer 0
# Node 647, type input, layer 0
# Node 648, type input, layer 0
# Node 649, type input, layer 0
# Node 650, type input, layer 0
# Node 651, type input, layer 0
# Node 652, type input, layer 0
# Node 653, type input, layer 0
# Node 654, type input, layer 0
# Node 655, type input, layer 0
# Node 656, type input, layer 0
# Node 657, type input, layer 0
# Node 658, type input, layer 0
# Node 659, type input, layer 0
# Node 660, type input, layer 0
# Node 661, type input, layer 0
# Node 662, type input, layer 0
# Node 663, type input, layer 0
# Node 664, type input, layer 0
# Node 665, type input, layer 0
# Node 666, type input, layer 0
# Node 667, type input, layer 0
# Node 668, type input, layer 0
# Node 669, type input, layer 0
# Node 670, type input, layer 0
# Node 671, type input, layer 0
# Node 672, type input, layer 0
# Node 673, type input, layer 0
# Node 674, type input, layer 0
# Node 675, type input, layer 0
# Node 676, type input, layer 0
# Node 677, type input, layer 0
# Node 678, type input, layer 0
# Node 679, type input, layer 0
# Node 680, type input, layer 0
# Node 681, type input, layer 0
# Node 682, type input, layer 0
# Node 683, type input, layer 0
# Node 684, type input, layer 0
# Node 685, type input, layer 0
# Node 686, type input, layer 0
# Node 687, type input, layer 0
# Node 688, type input, layer 0
# Node 689, type input, layer 0
# Node 690, type input, layer 0
# Node 691, type input, layer 0
# Node 692, type input, layer 0
# Node 693, type input, layer 0
# Node 694, type input, layer 0
# Node 695, type input, layer 0
# Node 696, type input, layer 0
# Node 697, type input, layer 0
# Node 698, type input, layer 0
# Node 699, type input, layer 0
# Node 700, type input, layer 0
# Node 701, type input, layer 0
# Node 702, type input, layer 0
# Node 703, type input, layer 0
# Node 704, type input, layer 0
# Node 705, type input, layer 0
# Node 706, type input, layer 0
# Node 707, type input, layer 0
# Node 708, type input, layer 0
# Node 709, type input, layer 0
# Node 710, type input, layer 0
# Node 711, type input, layer 0
# Node 712, type input, layer 0
# Node 713, type input, layer 0
# Node 714, type input, layer 0
# Node 715, type input, layer 0
# Node 716, type input, layer 0
# Node 717, type input, layer 0
# Node 718, type input, layer 0
# Node 719, type input, layer 0
# Node 720, type input, layer 0
# Node 721, type input, layer 0
# Node 722, type input, layer 0
# Node 723, type input, layer 0
# Node 724, type input, layer 0
# Node 725, type input, layer 0
# Node 726, type input, layer 0
# Node 727, type input, layer 0
# Node 728, type input, layer 0
# Node 729, type input, layer 0
# Node 730, type input, layer 0
# Node 731, type input, layer 0
# Node 732, type input, layer 0
# Node 733, type input, layer 0
# Node 734, type input, layer 0
# Node 735, type input, layer 0
# Node 736, type input, layer 0
# Node 737, type input, layer 0
# Node 738, type input, layer 0
# Node 739, type input, layer 0
# Node 740, type input, layer 0
# Node 741, type input, layer 0
# Node 742, type input, layer 0
# Node 743, type input, layer 0
# Node 744, type input, layer 0
# Node 745, type input, layer 0
# Node 746, type input, layer 0
# Node 747, type input, layer 0
# Node 748, type input, layer 0
# Node 749, type input, layer 0
# Node 750, type input, layer 0
# Node 751, type input, layer 0
# Node 752, type input, layer 0
# Node 753, type input, layer 0
# Node 754, type input, layer 0
# Node 755, type input, layer 0
# Node 756, type input, layer 0
# Node 757, type input, layer 0
# Node 758, type input, layer 0
# Node 759, type input, layer 0
# Node 760, type input, layer 0
# Node 761, type input, layer 0
# Node 762, type input, layer 0
# Node 763, type input, layer 0
# Node 764, type input, layer 0
# Node 765, type input, layer 0
# Node 766, type input, layer 0
# Node 767, type input, layer 0
# Node 768, type input, layer 0
# Node 769, type input, layer 0
# Node 770, type input, layer 0
# Node 771, type input, layer 0
# Node 772, type input, layer 0
# Node 773, type input, layer 0
# Node 774, type input, layer 0
# Node 775, type input, layer 0
# Node 776, type input, layer 0
# Node 777, type input, layer 0
# Node 778, type input, layer 0
# Node 779, type input, layer 0
# Node 780, type input, layer 0
# Node 781, type input, layer 0
# Node 782, type input, layer 0
# Node 783, type input, layer 0
# Node 784, type input, layer 0
# Node 785, type input, layer 0
# Node 786, type input, layer 0
# Node 787, type input, layer 0
# Node 788, type input, layer 0
# Node 789, type input, layer 0
# Node 790, type input, layer 0
# Node 791, type input, layer 0
# Node 792, type input, layer 0
# Node 793, type input, layer 0
# Node 794, type input, layer 0
# Node 795, type input, layer 0
# Node 796, type input, layer 0
# Node 797, type input, layer 0
# Node 798, type input, layer 0
# Node 799, type input, layer 0
# Node 800, type input, layer 0
# Node 801, type input, layer 0
# Node 802, type input, layer 0
# Node 803, type input, layer 0
# Node 804, type input, layer 0
# Node 805, type input, layer 0
# Node 806, type input, layer 0
# Node 807, type input, layer 0
# Node 808, type input, layer 0
# Node 809, type input, layer 0
# Node 810, type input, layer 0
# Node 811, type input, layer 0
# Node 812, type input, layer 0
# Node 813, type input, layer 0
# Node 814, type input, layer 0
# Node 815, type input, layer 0
# Node 816, type input, layer 0
# Node 817, type input, layer 0
# Node 818, type input, layer 0
# Node 819, type input, layer 0
# Node 820, type input, layer 0
# Node 821, type input, layer 0
# Node 822, type input, layer 0
# Node 823, type input, layer 0
# Node 824, type input, layer 0
# Node 825, type input, layer 0
# Node 826, type input, layer 0
# Node 827, type input, layer 0
# Node 828, type input, layer 0
# Node 829, type input, layer 0
# Node 830, type input, layer 0
# Node 831, type input, layer 0
# Node 832, type input, layer 0
# Node 833, type input, layer 0
# Node 834, type input, layer 0
# Node 835, type input, layer 0
# Node 836, type input, layer 0
# Node 837, type input, layer 0
# Node 838, type input, layer 0
# Node 839, type input, layer 0
# Node 840, type input, layer 0
# Node 841, type input, layer 0
# Node 842, type input, layer 0
# Node 843, type input, layer 0
# Node 844, type input, layer 0
# Node 845, type input, layer 0
# Node 846, type input, layer 0
# Node 847, type input, layer 0
# Node 848, type input, layer 0
# Node 849, type input, layer 0
# Node 850, type input, layer 0
# Node 851, type input, layer 0
# Node 852, type input, layer 0
# Node 853, type input, layer 0
# Node 854, type input, layer 0
# Node 855, type input, layer 0
# Node 856, type input, layer 0
# Node 857, type input, layer 0
# Node 858, type input, layer 0
# Node 859, type input, layer 0
# Node 860, type input, layer 0
# Node 861, type input, layer 0
# Node 862, type input, layer 0
# Node 863, type input, layer 0
# Node 864, type input, layer 0
# Node 865, type input, layer 0
# Node 866, type input, layer 0
# Node 867, type input, layer 0
# Node 868, type input, layer 0
# Node 869, type input, layer 0
# Node 870, type input, layer 0
# Node 871, type input, layer 0
# Node 872, type input, layer 0
# Node 873, type input, layer 0
# Node 874, type input, layer 0
# Node 875, type input, layer 0
# Node 876, type input, layer 0
# Node 877, type input, layer 0
# Node 878, type input, layer 0
# Node 879, type input, layer 0
# Node 880, type input, layer 0
# Node 881, type input, layer 0
# Node 882, type input, layer 0
# Node 883, type input, layer 0
# Node 884, type input, layer 0
# Node 885, type input, layer 0
# Node 886, type input, layer 0
# Node 887, type input, layer 0
# Node 888, type input, layer 0
# Node 889, type input, layer 0
# Node 890, type input, layer 0
# Node 891, type input, layer 0
# Node 892, type input, layer 0
# Node 893, type input, layer 0
# Node 894, type input, layer 0
# Node 895, type input, layer 0
# Node 896, type input, layer 0
# Node 897, type input, layer 0
# Node 898, type input, layer 0
# Node 899, type input, layer 0
# Node 900, type input, layer 0
# Node 901, type input, layer 0
# Node 902, type input, layer 0
# Node 903, type input, layer 0
# Node 904, type input, layer 0
# Node 905, type input, layer 0
# Node 906, type input, layer 0
# Node 907, type input, layer 0
# Node 908, type input, layer 0
# Node 909, type input, layer 0
# Node 910, type input, layer 0
# Node 911, type input, layer 0
# Node 912, type input, layer 0
# Node 913, type input, layer 0
# Node 914, type input, layer 0
# Node 915, type input, layer 0
# Node 916, type input, layer 0
# Node 917, type input, layer 0
# Node 918, type input, layer 0
# Node 919, type input, layer 0
# Node 920, type input, layer 0
# Node 921, type input, layer 0
# Node 922, type input, layer 0
# Node 923, type input, layer 0
# Node 924, type input, layer 0
# Node 925, type input, layer 0
# Node 926, type input, layer 0
# Node 927, type input, layer 0
# Node 928, type input, layer 0
# Node 929, type input, layer 0
# Node 930, type input, layer 0
# Node 931, type input, layer 0
# Node 932, type input, layer 0
# Node 933, type input, layer 0
# Node 934, type input, layer 0
# Node 935, type input, layer 0
# Node 936, type input, layer 0
# Node 937, type input, layer 0
# Node 938, type input, layer 0
# Node 939, type input, layer 0
# Node 940, type input, layer 0
# Node 941, type input, layer 0
# Node 942, type input, layer 0
# Node 943, type input, layer 0
# Node 944, type input, layer 0
# Node 945, type input, layer 0
# Node 946, type input, layer 0
# Node 947, type input, layer 0
# Node 948, type input, layer 0
# Node 949, type input, layer 0
# Node 950, type input, layer 0
# Node 951, type input, layer 0
# Node 952, type input, layer 0
# Node 953, type input, layer 0
# Node 954, type input, layer 0
# Node 955, type input, layer 0
# Node 956, type input, layer 0
# Node 957, type input, layer 0
# Node 958, type input, layer 0
# Node 959, type input, layer 0
# Node 960, type input, layer 0
# Node 961, type input, layer 0
# Node 962, type input, layer 0
# Node 963, type input, layer 0
# Node 964, type input, layer 0
# Node 965, type input, layer 0
# Node 966, type input, layer 0
# Node 967, type input, layer 0
# Node 968, type input, layer 0
# Node 969, type input, layer 0
# Node 970, type input, layer 0
# Node 971, type input, layer 0
# Node 972, type input, layer 0
# Node 973, type input, layer 0
# Node 974, type input, layer 0
# Node 975, type input, layer 0
# Node 976, type input, layer 0
# Node 977, type input, layer 0
# Node 978, type input, layer 0
# Node 979, type input, layer 0
# Node 980, type input, layer 0
# Node 981, type input, layer 0
# Node 982, type input, layer 0
# Node 983, type input, layer 0
# Node 984, type input, layer 0
# Node 985, type input, layer 0
# Node 986, type input, layer 0
# Node 987, type input, layer 0
# Node 988, type input, layer 0
# Node 989, type input, layer 0
# Node 990, type input, layer 0
# Node 991, type input, layer 0
# Node 992, type input, layer 0
# Node 993, type input, layer 0
# Node 994, type input, layer 0
# Node 995, type input, layer 0
# Node 996, type input, layer 0
# Node 997, type input, layer 0
# Node 998, type input, layer 0
# Node 999, type input, layer 0
# Node 1000, type input, layer 0
# Node 1001, type input, layer 0
# Node 1002, type input, layer 0
# Node 1003, type input, layer 0
# Node 1004, type input, layer 0
# Node 1005, type input, layer 0
# Node 1006, type input, layer 0
# Node 1007, type input, layer 0
# Node 1008, type input, layer 0
# Node 1009, type input, layer 0
# Node 1010, type input, layer 0
# Node 1011, type input, layer 0
# Node 1012, type input, layer 0
# Node 1013, type input, layer 0
# Node 1014, type input, layer 0
# Node 1015, type input, layer 0
# Node 1016, type input, layer 0
# Node 1017, type input, layer 0
# Node 1018, type input, layer 0
# Node 1019, type input, layer 0
# Node 1020, type input, layer 0
# Node 1021, type input, layer 0
# Node 1022, type input, layer 0
# Node 1023, type input, layer 0
# Node 1024, type input, layer 0
# Node 1025, type input, layer 0
# Node 1026, type input, layer 0
# Node 1027, type input, layer 0
# Node 1028, type input, layer 0
# Node 1029, type input, layer 0
# Node 1030, type input, layer 0
# Node 1031, type input, layer 0
# Node 1032, type input, layer 0
# Node 1033, type input, layer 0
# Node 1034, type input, layer 0
# Node 1035, type input, layer 0
# Node 1036, type input, layer 0
# Node 1037, type input, layer 0
# Node 1038, type input, layer 0
# Node 1039, type input, layer 0
# Node 1040, type input, layer 0
# Node 1041, type input, layer 0
# Node 1042, type input, layer 0
# Node 1043, type input, layer 0
# Node 1044, type input, layer 0
# Node 1045, type input, layer 0
# Node 1046, type input, layer 0
# Node 1047, type input, layer 0
# Node 1048, type input, layer 0
# Node 1049, type input, layer 0
# Node 1050, type input, layer 0
# Node 1051, type input, layer 0
# Node 1052, type input, layer 0
# Node 1053, type input, layer 0
# Node 1054, type input, layer 0
# Node 1055, type input, layer 0
# Node 1056, type input, layer 0
# Node 1057, type input, layer 0
# Node 1058, type input, layer 0
# Node 1059, type input, layer 0
# Node 1060, type input, layer 0
# Node 1061, type input, layer 0
# Node 1062, type input, layer 0
# Node 1063, type input, layer 0
# Node 1064, type input, layer 0
# Node 1065, type input, layer 0
# Node 1066, type input, layer 0
# Node 1067, type input, layer 0
# Node 1068, type input, layer 0
# Node 1069, type input, layer 0
# Node 1070, type input, layer 0
# Node 1071, type input, layer 0
# Node 1072, type input, layer 0
# Node 1073, type input, layer 0
# Node 1074, type input, layer 0
# Node 1075, type input, layer 0
# Node 1076, type input, layer 0
# Node 1077, type input, layer 0
# Node 1078, type input, layer 0
# Node 1079, type input, layer 0
# Node 1080, type input, layer 0
# Node 1081, type input, layer 0
# Node 1082, type input, layer 0
# Node 1083, type input, layer 0
# Node 1084, type input, layer 0
# Node 1085, type input, layer 0
# Node 1086, type input, layer 0
# Node 1087, type input, layer 0
# Node 1088, type input, layer 0
# Node 1089, type input, layer 0
# Node 1090, type input, layer 0
# Node 1091, type input, layer 0
# Node 1092, type input, layer 0
# Node 1093, type input, layer 0
# Node 1094, type input, layer 0
# Node 1095, type input, layer 0
# Node 1096, type input, layer 0
# Node 1097, type input, layer 0
# Node 1098, type input, layer 0
# Node 1099, type input, layer 0
# Node 1100, type input, layer 0
# Node 1101, type input, layer 0
# Node 1102, type input, layer 0
# Node 1103, type input, layer 0
# Node 1104, type input, layer 0
# Node 1105, type input, layer 0
# Node 1106, type input, layer 0
# Node 1107, type input, layer 0
# Node 1108, type input, layer 0
# Node 1109, type input, layer 0
# Node 1110, type input, layer 0
# Node 1111, type input, layer 0
# Node 1112, type input, layer 0
# Node 1113, type input, layer 0
# Node 1114, type input, layer 0
# Node 1115, type input, layer 0
# Node 1116, type input, layer 0
# Node 1117, type input, layer 0
# Node 1118, type input, layer 0
# Node 1119, type input, layer 0
# Node 1120, type input, layer 0
# Node 1121, type input, layer 0
# Node 1122, type input, layer 0
# Node 1123, type input, layer 0
# Node 1124, type input, layer 0
# Node 1125, type input, layer 0
# Node 1126, type input, layer 0
# Node 1127, type input, layer 0
# Node 1128, type input, layer 0
# Node 1129, type input, layer 0
# Node 1130, type input, layer 0
# Node 1131, type input, layer 0
# Node 1132, type input, layer 0
# Node 1133, type input, layer 0
# Node 1134, type input, layer 0
# Node 1135, type input, layer 0
# Node 1136, type input, layer 0
# Node 1137, type input, layer 0
# Node 1138, type input, layer 0
# Node 1139, type input, layer 0
# Node 1140, type input, layer 0
# Node 1141, type input, layer 0
# Node 1142, type input, layer 0
# Node 1143, type input, layer 0
# Node 1144, type input, layer 0
# Node 1145, type input, layer 0
# Node 1146, type input, layer 0
# Node 1147, type input, layer 0
# Node 1148, type input, layer 0
# Node 1149, type input, layer 0
# Node 1150, type input, layer 0
# Node 1151, type input, layer 0
# Node 1152, type input, layer 0
# Node 1153, type input, layer 0
# Node 1154, type input, layer 0
# Node 1155, type input, layer 0
# Node 1156, type input, layer 0
# Node 1157, type input, layer 0
# Node 1158, type input, layer 0
# Node 1159, type input, layer 0
# Node 1160, type input, layer 0
# Node 1161, type input, layer 0
# Node 1162, type input, layer 0
# Node 1163, type input, layer 0
# Node 1164, type input, layer 0
# Node 1165, type input, layer 0
# Node 1166, type input, layer 0
# Node 1167, type input, layer 0
# Node 1168, type input, layer 0
# Node 1169, type input, layer 0
# Node 1170, type input, layer 0
# Node 1171, type input, layer 0
# Node 1172, type input, layer 0
# Node 1173, type input, layer 0
# Node 1174, type input, layer 0
# Node 1175, type input, layer 0
# Node 1176, type input, layer 0
# Node 1177, type input, layer 0
# Node 1178, type input, layer 0
# Node 1179, type input, layer 0
# Node 1180, type input, layer 0
# Node 1181, type input, layer 0
# Node 1182, type input, layer 0
# Node 1183, type input, layer 0
# Node 1184, type input, layer 0
# Node 1185, type input, layer 0
# Node 1186, type input, layer 0
# Node 1187, type input, layer 0
# Node 1188, type input, layer 0
# Node 1189, type input, layer 0
# Node 1190, type input, layer 0
# Node 1191, type input, layer 0
# Node 1192, type input, layer 0
# Node 1193, type input, layer 0
# Node 1194, type input, layer 0
# Node 1195, type input, layer 0
# Node 1196, type input, layer 0
# Node 1197, type input, layer 0
# Node 1198, type input, layer 0
# Node 1199, type input, layer 0
# Node 1200, type input, layer 0
# Node 1201, type input, layer 0
# Node 1202, type input, layer 0
# Node 1203, type input, layer 0
# Node 1204, type input, layer 0
# Node 1205, type input, layer 0
# Node 1206, type input, layer 0
# Node 1207, type input, layer 0
# Node 1208, type input, layer 0
# Node 1209, type input, layer 0
# Node 1210, type input, layer 0
# Node 1211, type input, layer 0
# Node 1212, type input, layer 0
# Node 1213, type input, layer 0
# Node 1214, type input, layer 0
# Node 1215, type input, layer 0
# Node 1216, type input, layer 0
# Node 1217, type input, layer 0
# Node 1218, type input, layer 0
# Node 1219, type input, layer 0
# Node 1220, type input, layer 0
# Node 1221, type input, layer 0
# Node 1222, type input, layer 0
# Node 1223, type input, layer 0
# Node 1224, type input, layer 0
# Node 1225, type input, layer 0
# Node 1226, type input, layer 0
# Node 1227, type input, layer 0
# Node 1228, type input, layer 0
# Node 1229, type input, layer 0
# Node 1230, type input, layer 0
# Node 1231, type input, layer 0
# Node 1232, type input, layer 0
# Node 1233, type input, layer 0
# Node 1234, type input, layer 0
# Node 1235, type input, layer 0
# Node 1236, type input, layer 0
# Node 1237, type input, layer 0
# Node 1238, type input, layer 0
# Node 1239, type input, layer 0
# Node 1240, type input, layer 0
# Node 1241, type input, layer 0
# Node 1242, type input, layer 0
# Node 1243, type input, layer 0
# Node 1244, type input, layer 0
# Node 1245, type input, layer 0
# Node 1246, type input, layer 0
# Node 1247, type input, layer 0
# Node 1248, type input, layer 0
# Node 1249, type input, layer 0
# Node 1250, type input, layer 0
# Node 1251, type input, layer 0
# Node 1252, type input, layer 0
# Node 1253, type input, layer 0
# Node 1254, type input, layer 0
# Node 1255, type input, layer 0
# Node 1256, type input, layer 0
# Node 1257, type input, layer 0
# Node 1258, type input, layer 0
# Node 1259, type input, layer 0
# Node 1260, type input, layer 0
# Node 1261, type input, layer 0
# Node 1262, type input, layer 0
# Node 1263, type input, layer 0
# Node 1264, type input, layer 0
# Node 1265, type input, layer 0
# Node 1266, type input, layer 0
# Node 1267, type input, layer 0
# Node 1268, type input, layer 0
# Node 1269, type input, layer 0
# Node 1270, type input, layer 0
# Node 1271, type input, layer 0
# Node 1272, type input, layer 0
# Node 1273, type input, layer 0
# Node 1274, type input, layer 0
# Node 1275, type input, layer 0
# Node 1276, type input, layer 0
# Node 1277, type input, layer 0
# Node 1278, type input, layer 0
# Node 1279, type input, layer 0
# Node 1280, type input, layer 0
# Node 1281, type input, layer 0
# Node 1282, type input, layer 0
# Node 1283, type input, layer 0
# Node 1284, type input, layer 0
# Node 1285, type input, layer 0
# Node 1286, type input, layer 0
# Node 1287, type input, layer 0
# Node 1288, type input, layer 0
# Node 1289, type input, layer 0
# Node 1290, type input, layer 0
# Node 1291, type input, layer 0
# Node 1292, type input, layer 0
# Node 1293, type input, layer 0
# Node 1294, type input, layer 0
# Node 1295, type input, layer 0
# Node 1296, type input, layer 0
# Node 1297, type input, layer 0
# Node 1298, type input, layer 0
# Node 1299, type input, layer 0
# Node 1300, type input, layer 0
# Node 1301, type input, layer 0
# Node 1302, type input, layer 0
# Node 1303, type input, layer 0
# Node 1304, type input, layer 0
# Node 1305, type input, layer 0
# Node 1306, type input, layer 0
# Node 1307, type input, layer 0
# Node 1308, type input, layer 0
# Node 1309, type input, layer 0
# Node 1310, type input, layer 0
# Node 1311, type input, layer 0
# Node 1312, type input, layer 0
# Node 1313, type input, layer 0
# Node 1314, type input, layer 0
# Node 1315, type input, layer 0
# Node 1316, type input, layer 0
# Node 1317, type input, layer 0
# Node 1318, type input, layer 0
# Node 1319, type input, layer 0
# Node 1320, type input, layer 0
# Node 1321, type input, layer 0
# Node 1322, type input, layer 0
# Node 1323, type input, layer 0
# Node 1324, type input, layer 0
# Node 1325, type input, layer 0
# Node 1326, type input, layer 0
# Node 1327, type input, layer 0
# Node 1328, type input, layer 0
# Node 1329, type input, layer 0
# Node 1330, type input, layer 0
# Node 1331, type input, layer 0
# Node 1332, type input, layer 0
# Node 1333, type input, layer 0
# Node 1334, type input, layer 0
# Node 1335, type input, layer 0
# Node 1336, type input, layer 0
# Node 1337, type input, layer 0
# Node 1338, type input, layer 0
# Node 1339, type input, layer 0
# Node 1340, type input, layer 0
# Node 1341, type input, layer 0
# Node 1342, type input, layer 0
# Node 1343, type input, layer 0
# Node 1344, type input, layer 0
# Node 1345, type input, layer 0
# Node 1346, type input, layer 0
# Node 1347, type input, layer 0
# Node 1348, type input, layer 0
# Node 1349, type input, layer 0
# Node 1350, type input, layer 0
# Node 1351, type input, layer 0
# Node 1352, type input, layer 0
# Node 1353, type input, layer 0
# Node 1354, type input, layer 0
# Node 1355, type input, layer 0
# Node 1356, type input, layer 0
# Node 1357, type input, layer 0
# Node 1358, type input, layer 0
# Node 1359, type input, layer 0
# Node 1360, type input, layer 0
# Node 1361, type input, layer 0
# Node 1362, type input, layer 0
# Node 1363, type input, layer 0
# Node 1364, type input, layer 0
# Node 1365, type input, layer 0
# Node 1366, type input, layer 0
# Node 1367, type input, layer 0
# Node 1368, type input, layer 0
# Node 1369, type input, layer 0
# Node 1370, type input, layer 0
# Node 1371, type input, layer 0
# Node 1372, type input, layer 0
# Node 1373, type input, layer 0
# Node 1374, type input, layer 0
# Node 1375, type input, layer 0
# Node 1376, type input, layer 0
# Node 1377, type input, layer 0
# Node 1378, type input, layer 0
# Node 1379, type input, layer 0
# Node 1380, type input, layer 0
# Node 1381, type input, layer 0
# Node 1382, type input, layer 0
# Node 1383, type input, layer 0
# Node 1384, type input, layer 0
# Node 1385, type input, layer 0
# Node 1386, type input, layer 0
# Node 1387, type input, layer 0
# Node 1388, type input, layer 0
# Node 1389, type input, layer 0
# Node 1390, type input, layer 0
# Node 1391, type input, layer 0
# Node 1392, type input, layer 0
# Node 1393, type input, layer 0
# Node 1394, type input, layer 0
# Node 1395, type input, layer 0
# Node 1396, type input, layer 0
# Node 1397, type input, layer 0
# Node 1398, type input, layer 0
# Node 1399, type input, layer 0
# ...
# Node 24010, type input, layer 0
# Node 24011, type input, layer 0
# Node 24012, type input, layer 0
# Node 24013, type input, layer 0
# Node 24014, type input, layer 0
# Node 24015, type input, layer 0
# Node 24016, type input, layer 0
# Node 24017, type input, layer 0
# Node 24018, type input, layer 0
# Node 24019, type input, layer 0
# Node 24020, type input, layer 0
# Node 24021, type input, layer 0
# Node 24022, type input, layer 0
# Node 24023, type input, layer 0
# Node 24024, type input, layer 0
# Node 24025, type input, layer 0
# Node 24026, type input, layer 0
# Node 24027, type input, layer 0
# Node 24028, type input, layer 0
# Node 24029, type input, layer 0
# Node 24030, type input, layer 0
# Node 24031, type input, layer 0
# Node 24032, type input, layer 0
# Node 24033, type input, layer 0
# Node 24034, type input, layer 0
# Node 24035, type input, layer 0
# Node 24036, type input, layer 0
# Node 24037, type input, layer 0
# Node 24038, type input, layer 0
# Node 24039, type input, layer 0
# Node 24040, type input, layer 0
# Node 24041, type input, layer 0
# Node 24042, type input, layer 0
# Node 24043, type input, layer 0
# Node 24044, type input, layer 0
# Node 24045, type input, layer 0
# Node 24046, type input, layer 0
# Node 24047, type input, layer 0
# Node 24048, type input, layer 0
# Node 24049, type input, layer 0
# Node 24050, type input, layer 0
# Node 24051, type input, layer 0
# Node 24052, type input, layer 0
# Node 24053, type input, layer 0
# Node 24054, type input, layer 0
# Node 24055, type input, layer 0
# Node 24056, type input, layer 0
# Node 24057, type input, layer 0
# Node 24058, type input, layer 0
# Node 24059, type input, layer 0
# Node 24060, type input, layer 0
# Node 24061, type input, layer 0
# Node 24062, type input, layer 0
# Node 24063, type input, layer 0
# Node 24064, type input, layer 0
# Node 24065, type input, layer 0
# Node 24066, type input, layer 0
# Node 24067, type input, layer 0
# Node 24068, type input, layer 0
# Node 24069, type input, layer 0
# Node 24070, type input, layer 0
# Node 24071, type input, layer 0
# Node 24072, type input, layer 0
# Node 24073, type input, layer 0
# Node 24074, type input, layer 0
# Node 24075, type input, layer 0
# Node 24076, type input, layer 0
# Node 24077, type input, layer 0
# Node 24078, type input, layer 0
# Node 24079, type input, layer 0
# Node 24080, type input, layer 0
# Node 24081, type input, layer 0
# Node 24082, type input, layer 0
# Node 24083, type input, layer 0
# Node 24084, type input, layer 0
# Node 24085, type input, layer 0
# Node 24086, type input, layer 0
# Node 24087, type input, layer 0
# Node 24088, type input, layer 0
# Node 24089, type input, layer 0
# Node 24090, type input, layer 0
# Node 24091, type input, layer 0
# Node 24092, type input, layer 0
# Node 24093, type input, layer 0
# Node 24094, type input, layer 0
# Node 24095, type input, layer 0
# Node 24096, type input, layer 0
# Node 24097, type input, layer 0
# Node 24098, type input, layer 0
# Node 24099, type input, layer 0
# Node 24100, type input, layer 0
# Node 24101, type input, layer 0
# Node 24102, type input, layer 0
# Node 24103, type input, layer 0
# Node 24104, type input, layer 0
# Node 24105, type input, layer 0
# Node 24106, type input, layer 0
# Node 24107, type input, layer 0
# Node 24108, type input, layer 0
# Node 24109, type input, layer 0
# Node 24110, type input, layer 0
# Node 24111, type input, layer 0
# Node 24112, type input, layer 0
# Node 24113, type input, layer 0
# Node 24114, type input, layer 0
# Node 24115, type input, layer 0
# Node 24116, type input, layer 0
# Node 24117, type input, layer 0
# Node 24118, type input, layer 0
# Node 24119, type input, layer 0
# Node 24120, type input, layer 0
# Node 24121, type input, layer 0
# Node 24122, type input, layer 0
# Node 24123, type input, layer 0
# Node 24124, type input, layer 0
# Node 24125, type input, layer 0
# Node 24126, type input, layer 0
# Node 24127, type input, layer 0
# Node 24128, type input, layer 0
# Node 24129, type input, layer 0
# Node 24130, type input, layer 0
# Node 24131, type input, layer 0
# Node 24132, type input, layer 0
# Node 24133, type input, layer 0
# Node 24134, type input, layer 0
# Node 24135, type input, layer 0
# Node 24136, type input, layer 0
# Node 24137, type input, layer 0
# Node 24138, type input, layer 0
# Node 24139, type input, layer 0
# Node 24140, type input, layer 0
# Node 24141, type input, layer 0
# Node 24142, type input, layer 0
# Node 24143, type input, layer 0
# Node 24144, type input, layer 0
# Node 24145, type input, layer 0
# Node 24146, type input, layer 0
# Node 24147, type input, layer 0
# Node 24148, type input, layer 0
# Node 24149, type input, layer 0
# Node 24150, type input, layer 0
# Node 24151, type input, layer 0
# Node 24152, type input, layer 0
# Node 24153, type input, layer 0
# Node 24154, type input, layer 0
# Node 24155, type input, layer 0
# Node 24156, type input, layer 0
# Node 24157, type input, layer 0
# Node 24158, type input, layer 0
# Node 24159, type input, layer 0
# Node 24160, type input, layer 0
# Node 24161, type input, layer 0
# Node 24162, type input, layer 0
# Node 24163, type input, layer 0
# Node 24164, type input, layer 0
# Node 24165, type input, layer 0
# Node 24166, type input, layer 0
# Node 24167, type input, layer 0
# Node 24168, type input, layer 0
# Node 24169, type input, layer 0
# Node 24170, type input, layer 0
# Node 24171, type input, layer 0
# Node 24172, type input, layer 0
# Node 24173, type input, layer 0
# Node 24174, type input, layer 0
# Node 24175, type input, layer 0
# Node 24176, type input, layer 0
# Node 24177, type input, layer 0
# Node 24178, type input, layer 0
# Node 24179, type input, layer 0
# Node 24180, type input, layer 0
# Node 24181, type input, layer 0
# Node 24182, type input, layer 0
# Node 24183, type input, layer 0
# Node 24184, type input, layer 0
# Node 24185, type input, layer 0
# Node 24186, type input, layer 0
# Node 24187, type input, layer 0
# Node 24188, type input, layer 0
# Node 24189, type input, layer 0
# Node 24190, type input, layer 0
# Node 24191, type input, layer 0
# Node 24192, type input, layer 0
# Node 24193, type input, layer 0
# Node 24194, type input, layer 0
# Node 24195, type input, layer 0
# Node 24196, type input, layer 0
# Node 24197, type input, layer 0
# Node 24198, type input, layer 0
# Node 24199, type input, layer 0
# Node 24200, type input, layer 0
# Node 24201, type input, layer 0
# Node 24202, type input, layer 0
# Node 24203, type input, layer 0
# Node 24204, type input, layer 0
# Node 24205, type input, layer 0
# Node 24206, type input, layer 0
# Node 24207, type input, layer 0
# Node 24208, type input, layer 0
# Node 24209, type input, layer 0
# Node 24210, type input, layer 0
# Node 24211, type input, layer 0
# Node 24212, type input, layer 0
# Node 24213, type input, layer 0
# Node 24214, type input, layer 0
# Node 24215, type input, layer 0
# Node 24216, type input, layer 0
# Node 24217, type input, layer 0
# Node 24218, type input, layer 0
# Node 24219, type input, layer 0
# Node 24220, type input, layer 0
# Node 24221, type input, layer 0
# Node 24222, type input, layer 0
# Node 24223, type input, layer 0
# Node 24224, type input, layer 0
# Node 24225, type input, layer 0
# Node 24226, type input, layer 0
# Node 24227, type input, layer 0
# Node 24228, type input, layer 0
# Node 24229, type input, layer 0
# Node 24230, type input, layer 0
# Node 24231, type input, layer 0
# Node 24232, type input, layer 0
# Node 24233, type input, layer 0
# Node 24234, type input, layer 0
# Node 24235, type input, layer 0
# Node 24236, type input, layer 0
# Node 24237, type input, layer 0
# Node 24238, type input, layer 0
# Node 24239, type input, layer 0
# Node 24240, type input, layer 0
# Node 24241, type input, layer 0
# Node 24242, type input, layer 0
# Node 24243, type input, layer 0
# Node 24244, type input, layer 0
# Node 24245, type input, layer 0
# Node 24246, type input, layer 0
# Node 24247, type input, layer 0
# Node 24248, type input, layer 0
# Node 24249, type input, layer 0
# Node 24250, type input, layer 0
# Node 24251, type input, layer 0
# Node 24252, type input, layer 0
# Node 24253, type input, layer 0
# Node 24254, type input, layer 0
# Node 24255, type input, layer 0
# Node 24256, type input, layer 0
# Node 24257, type input, layer 0
# Node 24258, type input, layer 0
# Node 24259, type input, layer 0
# Node 24260, type input, layer 0
# Node 24261, type input, layer 0
# Node 24262, type input, layer 0
# Node 24263, type input, layer 0
# Node 24264, type input, layer 0
# Node 24265, type input, layer 0
# Node 24266, type input, layer 0
# Node 24267, type input, layer 0
# Node 24268, type input, layer 0
# Node 24269, type input, layer 0
# Node 24270, type input, layer 0
# Node 24271, type input, layer 0
# Node 24272, type input, layer 0
# Node 24273, type input, layer 0
# Node 24274, type input, layer 0
# Node 24275, type input, layer 0
# Node 24276, type input, layer 0
# Node 24277, type input, layer 0
# Node 24278, type input, layer 0
# Node 24279, type input, layer 0
# Node 24280, type input, layer 0
# Node 24281, type input, layer 0
# Node 24282, type input, layer 0
# Node 24283, type input, layer 0
# Node 24284, type input, layer 0
# Node 24285, type input, layer 0
# Node 24286, type input, layer 0
# Node 24287, type input, layer 0
# Node 24288, type input, layer 0
# Node 24289, type input, layer 0
# Node 24290, type input, layer 0
# Node 24291, type input, layer 0
# Node 24292, type input, layer 0
# Node 24293, type input, layer 0
# Node 24294, type input, layer 0
# Node 24295, type input, layer 0
# Node 24296, type input, layer 0
# Node 24297, type input, layer 0
# Node 24298, type input, layer 0
# Node 24299, type input, layer 0
# Node 24300, type input, layer 0
# Node 24301, type input, layer 0
# Node 24302, type input, layer 0
# Node 24303, type input, layer 0
# Node 24304, type input, layer 0
# Node 24305, type input, layer 0
# Node 24306, type input, layer 0
# Node 24307, type input, layer 0
# Node 24308, type input, layer 0
# Node 24309, type input, layer 0
# Node 24310, type input, layer 0
# Node 24311, type input, layer 0
# Node 24312, type input, layer 0
# Node 24313, type input, layer 0
# Node 24314, type input, layer 0
# Node 24315, type input, layer 0
# Node 24316, type input, layer 0
# Node 24317, type input, layer 0
# Node 24318, type input, layer 0
# Node 24319, type input, layer 0
# Node 24320, type input, layer 0
# Node 24321, type input, layer 0
# Node 24322, type input, layer 0
# Node 24323, type input, layer 0
# Node 24324, type input, layer 0
# Node 24325, type input, layer 0
# Node 24326, type input, layer 0
# Node 24327, type input, layer 0
# Node 24328, type input, layer 0
# Node 24329, type input, layer 0
# Node 24330, type input, layer 0
# Node 24331, type input, layer 0
# Node 24332, type input, layer 0
# Node 24333, type input, layer 0
# Node 24334, type input, layer 0
# Node 24335, type input, layer 0
# Node 24336, type input, layer 0
# Node 24337, type input, layer 0
# Node 24338, type input, layer 0
# Node 24339, type input, layer 0
# Node 24340, type input, layer 0
# Node 24341, type input, layer 0
# Node 24342, type input, layer 0
# Node 24343, type input, layer 0
# Node 24344, type input, layer 0
# Node 24345, type input, layer 0
# Node 24346, type input, layer 0
# Node 24347, type input, layer 0
# Node 24348, type input, layer 0
# Node 24349, type input, layer 0
# Node 24350, type input, layer 0
# Node 24351, type input, layer 0
# Node 24352, type input, layer 0
# Node 24353, type input, layer 0
# Node 24354, type input, layer 0
# Node 24355, type input, layer 0
# Node 24356, type input, layer 0
# Node 24357, type input, layer 0
# Node 24358, type input, layer 0
# Node 24359, type input, layer 0
# Node 24360, type input, layer 0
# Node 24361, type input, layer 0
# Node 24362, type input, layer 0
# Node 24363, type input, layer 0
# Node 24364, type input, layer 0
# Node 24365, type input, layer 0
# Node 24366, type input, layer 0
# Node 24367, type input, layer 0
# Node 24368, type input, layer 0
# Node 24369, type input, layer 0
# Node 24370, type input, layer 0
# Node 24371, type input, layer 0
# Node 24372, type input, layer 0
# Node 24373, type input, layer 0
# Node 24374, type input, layer 0
# Node 24375, type input, layer 0
# Node 24376, type input, layer 0
# Node 24377, type input, layer 0
# Node 24378, type input, layer 0
# Node 24379, type input, layer 0
# Node 24380, type input, layer 0
# Node 24381, type input, layer 0
# Node 24382, type input, layer 0
# Node 24383, type input, layer 0
# Node 24384, type input, layer 0
# Node 24385, type input, layer 0
# Node 24386, type input, layer 0
# Node 24387, type input, layer 0
# Node 24388, type input, layer 0
# Node 24389, type input, layer 0
# Node 24390, type input, layer 0
# Node 24391, type input, layer 0
# Node 24392, type input, layer 0
# Node 24393, type input, layer 0
# Node 24394, type input, layer 0
# Node 24395, type input, layer 0
# Node 24396, type input, layer 0
# Node 24397, type input, layer 0
# Node 24398, type input, layer 0
# Node 24399, type input, layer 0
# Node 24400, type input, layer 0
# Node 24401, type input, layer 0
# Node 24402, type input, layer 0
# Node 24403, type input, layer 0
# Node 24404, type input, layer 0
# Node 24405, type input, layer 0
# Node 24406, type input, layer 0
# Node 24407, type input, layer 0
# Node 24408, type input, layer 0
# Node 24409, type input, layer 0
# Node 24410, type input, layer 0
# Node 24411, type input, layer 0
# Node 24412, type input, layer 0
# Node 24413, type input, layer 0
# Node 24414, type input, layer 0
# Node 24415, type input, layer 0
# Node 24416, type input, layer 0
# Node 24417, type input, layer 0
# Node 24418, type input, layer 0
# Node 24419, type input, layer 0
# Node 24420, type input, layer 0
# Node 24421, type input, layer 0
# Node 24422, type input, layer 0
# Node 24423, type input, layer 0
# Node 24424, type input, layer 0
# Node 24425, type input, layer 0
# Node 24426, type input, layer 0
# Node 24427, type input, layer 0
# Node 24428, type input, layer 0
# Node 24429, type input, layer 0
# Node 24430, type input, layer 0
# Node 24431, type input, layer 0
# Node 24432, type input, layer 0
# Node 24433, type input, layer 0
# Node 24434, type input, layer 0
# Node 24435, type input, layer 0
# Node 24436, type input, layer 0
# Node 24437, type input, layer 0
# Node 24438, type input, layer 0
# Node 24439, type input, layer 0
# Node 24440, type input, layer 0
# Node 24441, type input, layer 0
# Node 24442, type input, layer 0
# Node 24443, type input, layer 0
# Node 24444, type input, layer 0
# Node 24445, type input, layer 0
# Node 24446, type input, layer 0
# Node 24447, type input, layer 0
# Node 24448, type input, layer 0
# Node 24449, type input, layer 0
# Node 24450, type input, layer 0
# Node 24451, type input, layer 0
# Node 24452, type input, layer 0
# Node 24453, type input, layer 0
# Node 24454, type input, layer 0
# Node 24455, type input, layer 0
# Node 24456, type input, layer 0
# Node 24457, type input, layer 0
# Node 24458, type input, layer 0
# Node 24459, type input, layer 0
# Node 24460, type input, layer 0
# Node 24461, type input, layer 0
# Node 24462, type input, layer 0
# Node 24463, type input, layer 0
# Node 24464, type input, layer 0
# Node 24465, type input, layer 0
# Node 24466, type input, layer 0
# Node 24467, type input, layer 0
# Node 24468, type input, layer 0
# Node 24469, type input, layer 0
# Node 24470, type input, layer 0
# Node 24471, type input, layer 0
# Node 24472, type input, layer 0
# Node 24473, type input, layer 0
# Node 24474, type input, layer 0
# Node 24475, type input, layer 0
# Node 24476, type input, layer 0
# Node 24477, type input, layer 0
# Node 24478, type input, layer 0
# Node 24479, type input, layer 0
# Node 24480, type input, layer 0
# Node 24481, type input, layer 0
# Node 24482, type output, layer 3
# Node 24494, type hidden, layer 2
# Node 24708, type hidden, layer 1
# Connection genes:
# Connection 95: Input node id = 8508, Output node id = 24482, Weight = 0.6846772490560836, Enabled = True
# Connection 122: Input node id = 11372, Output node id = 24482, Weight = -4.616371264268236, Enabled = False
# Connection 145: Input node id = 11372, Output node id = 24494, Weight = -3.0200158363066967, Enabled = True
# Connection 146: Input node id = 24494, Output node id = 24482, Weight = 0.02409657387333164, Enabled = True
# Connection 172: Input node id = 18550, Output node id = 24494, Weight = 4.439209032407214, Enabled = False
# Connection 809: Input node id = 18550, Output node id = 24708, Weight = 0.244688320852674, Enabled = True
# Connection 810: Input node id = 24708, Output node id = 24494, Weight = 4.5982488084396405, Enabled = True
# Fitness: 99.21478271484375

# %%
acc, fitness = neat.evaluate(neat.best_solution, neat.x_train, neat.y_train)
print(f'Train dataset: fitness = {fitness}, accuracy = {acc} ')

acc, fitness = neat.evaluate(neat.best_solution, x_test, y_test)
print(f'Test dataset: fitness = {fitness}, accuracy = {acc} ')
# Out:
# Train dataset: fitness = 99.21478271484375, accuracy = 0.6666666865348816
# Test dataset: fitness = 96.86466979980469, accuracy = 0.6842105388641357
